# %% [markdown]
# # ArticleClient Demo
#
# **Main Points:**
# - Fast article metadata retrieval
# - Citation and reference analysis
# - Supplementary data and cross-references
# - Robust error handling

# %%
from pyeuropepmc.article import ArticleClient
article_client = ArticleClient()
article_id = "34308300"
article_source = "MED"

# Fast metadata retrieval
article = article_client.get_article_details(article_source, article_id)
print(f"Title: {article.get('result', {}).get('title', 'N/A')}")
print(f"Journal: {article.get('result', {}).get('journalInfo', {}).get('journal', {}).get('title', 'N/A')}")
print(f"Authors: {len(article.get('result', {}).get('authorList', {}).get('author', []))}")
# Out:
# Title: Characterizing long COVID in an international cohort: 7 months of symptoms and their impact.
# Journal: EClinicalMedicine
# Authors: 9

# %%
# Citation and reference analysis
citations = article_client.get_citations(article_source, article_id)

citation_count = len(citations.get('citationList', {}).get('citation', []))
references = article_client.get_references(article_source, article_id)
reference_count = len(references.get('referenceList', {}).get('reference', []))
print(f"Citations: {citation_count}")
print(f"References: {reference_count}")
# Out:
# Citations: 25
# References: 25

# %%
citations
# Out:
# {'version': '6.9',
#  'hitCount': 1741,
#  'request': {'id': '34308300', 'source': 'MED', 'offSet': 0, 'pageSize': 25},
#  'citationList': {'citation': [{'id': 'PPR1078485',
#     'source': 'PPR',
#     'citationType': 'preprint',
#     'title': 'Association between COVID-19 Vaccination and Long COVID Symptoms among Adult Residents of Belém, Brazilian Amazon: A Cross-Sectional Study',
#     'authorString': 'Silva LCM, Silva CC, Xavier SS, Tavares PR, Vasconcelos LA, Panzetti TMN, Quaresma JAS, Falcão LFM.',
#     'pubYear': 2025,
#     'citedByCount': 0},
#    {'id': '40903751',
#     'source': 'MED',
#     'citationType': 'research-article; journal article',
#     'title': 'Post-COVID syndrome in symptomatic COVID-19 patients: a retrospective cohort study.',
#     'authorString': 'Nguyen NN, Tissot-Dupont H, Brouqui P, Gautret P.',
#     'journalAbbreviation': 'BMC Infect Dis',
#     'pubYear': 2025,
#     'volume': '25',
#     'issue': '1',
#     'pageInfo': '1099',
#     'citedByCount': 0},
#    {'id': '40919112',
#     'source': 'MED',
#     'citationType': 'research-article; journal article',
#     'title': 'Associations Between Inflammatory and Catecholamine Markers and Clinical Outcomes in People with Post-Acute SARS-CoV-2 Infection.',
#     'authorString': 'Gerber LH, Estep M, De Avila L, Price JK, Weinstein AA, Stepanova M, Birerdinc A, Younossi Z.',
#     'journalAbbreviation': 'Int J Gen Med',
#     'pubYear': 2025,
#     'volume': '18',
#     'pageInfo': '4975-4985',
#     'citedByCount': 0},
#    {'id': '40897497',
#     'source': 'MED',
#     'citationType': 'research-article; journal article',
#     'title': 'Establishing a framework of measurement for use in Long COVID research and practice: protocol for a scoping review involving evidence review and consultation.',
#     'authorString': "McDuff K, Bhéreur A, Kadakia Z, Corrales-Medina VF, Gross DP, Janaudis-Ferreira T, Lam G, Naik H, Paterson TSE, Sanchez-Ramirez DC, Sasseville M, Sekar A, Vohra S, Bayley M, Birch S, Busse JW, Cameron JI, Kaup C, Cheung A, Churchill K, Edgell H, Goulding S, Hamilton C, Jaglal S, Kumar P, Levin A, Munblit D, Naye F, O'Hara M, Plaismond J, Rutledge M, Supper JW, Quinn K, Wasilewski MB, Wilkins A, O'Brien KK.",
#     'journalAbbreviation': 'BMJ Open',
#     'pubYear': 2025,
#     'volume': '15',
#     'issue': '9',
#     'pageInfo': 'e094497',
#     'citedByCount': 0},
#    {'id': '40892700',
#     'source': 'MED',
#     'citationType': 'research-article; journal article',
#     'title': 'Long COVID and chronic fatigue syndrome/myalgic encephalitis share similar pathophysiologic mechanisms of exercise limitation.',
#     'authorString': 'Jothi S, Insel M, Claessen G, Kubba S, Howden EJ, Ruiz-Carmona S, Levine T, Rischard FP.',
#     'journalAbbreviation': 'Physiol Rep',
#     'pubYear': 2025,
#     'volume': '13',
#     'issue': '17',
#     'pageInfo': 'e70535',
#     'citedByCount': 0},
#    {'id': '40887598',
#     'source': 'MED',
#     'citationType': 'journal article',
#     'title': 'Development and internal validation of a prediction model for post-COVID-19 condition 2\xa0years after infection-results of the CORFU study.',
#     'authorString': 'Klein DO, Wilmes N, Waardenburg SF, Bonsel GJ, Birnie E, Wintjens MS, Heemskerk SC, Janssen EB, Ghossein-Doha C, Warlé MC, Jacobs LM, Hemmen B, Verbunt JA, van Bussel BC, van Santen S, Kietselaer BL, Jansen G, Asselbergs FW, Linschoten M, Haagsma JA, van Kuijk SMJ, CAPACITY-COVID Collaborative Consortium.',
#     'journalAbbreviation': 'Diagn Progn Res',
#     'pubYear': 2025,
#     'volume': '9',
#     'issue': '1',
#     'pageInfo': '18',
#     'citedByCount': 0},
#    {'id': '40880174',
#     'source': 'MED',
#     'citationType': 'research-article; journal article',
#     'title': 'Symptoms and Risk Factors for Long COVID: A Cross-Sectional Study in Primary Care.',
#     'authorString': 'Ferreira AMS, Ferreira FELL, Alverga CCF, Nascimento JAD, de Carvalho ALB, de Freitas GRM, de Moraes JAC, Rocha IDS, Silva LTD, Alves BCPDS, de Oliveira CR, Cardoso JRA, Anacleto RMM, Pernambuco L.',
#     'journalAbbreviation': 'J Med Virol',
#     'pubYear': 2025,
#     'volume': '97',
#     'issue': '9',
#     'pageInfo': 'e70579',
#     'citedByCount': 0},
#    {'id': 'PPR1074014',
#     'source': 'PPR',
#     'citationType': 'preprint',
#     'title': 'Post-COVID Condition and Disparities in Daily Functional Activities: Findings from Virus Watch - a prospective community cohort study',
#     'authorString': 'Fong WLE, Beale S, Nguyen VG, Kovar J, Yavlinsky A, Hayward AC, Abubakar I, van Kuijk SM, Aldridge RW.',
#     'pubYear': 2025,
#     'citedByCount': 0},
#    {'id': '40850755',
#     'source': 'MED',
#     'citationType': 'journal article',
#     'title': 'Expert consensus on combination antiviral therapy for high-risk COVID-19 patients: A timely call to action.',
#     'authorString': 'Chen G, Lu H.',
#     'journalAbbreviation': 'Biosci Trends',
#     'pubYear': 2025,
#     'citedByCount': 0},
#    {'id': '40917240',
#     'source': 'MED',
#     'citationType': 'research-article; journal article',
#     'title': 'The non-linear association of physical fatigue with depression and anxiety among mental health professionals who recovered from COVID-19 infection: a national survey in China.',
#     'authorString': 'Wang YC, Huang YR, Sun HL, Feng Y, Chen P, Su Z, Cheung T, Ungvari GS, Balbuena L, An FR, Xiang YT, Wang G.',
#     'journalAbbreviation': 'Front Psychiatry',
#     'pubYear': 2025,
#     'volume': '16',
#     'pageInfo': '1610910',
#     'citedByCount': 0},
#    {'id': '40857408',
#     'source': 'MED',
#     'citationType': 'review-article; review; journal article',
#     'title': 'The role of complement in long COVID pathogenesis.',
#     'authorString': 'Bayarri-Olmos R, Bain W, Iwasaki A.',
#     'journalAbbreviation': 'JCI Insight',
#     'pubYear': 2025,
#     'volume': '10',
#     'issue': '16',
#     'pageInfo': 'e194314',
#     'citedByCount': 0},
#    {'id': '40917843',
#     'source': 'MED',
#     'citationType': 'brief-report; journal article',
#     'title': 'Challenges in diagnosis and treatment of long COVID.',
#     'authorString': 'Gu L, Yue J, Lin J, Liu Z, Huang JA.',
#     'journalAbbreviation': 'Front Med (Lausanne)',
#     'pubYear': 2025,
#     'volume': '12',
#     'pageInfo': '1641411',
#     'citedByCount': 0},
#    {'id': '40904575',
#     'source': 'MED',
#     'citationType': 'review-article; review; journal article',
#     'title': 'Exploring the psychological impact of long COVID: symptoms, mechanisms, and treatments.',
#     'authorString': 'Shen S, Zhao X, Pei J, Wang B, Hou J, Chai R, Guo Y, Li F, Hao J, Wu Z.',
#     'journalAbbreviation': 'Front Psychiatry',
#     'pubYear': 2025,
#     'volume': '16',
#     'pageInfo': '1555370',
#     'citedByCount': 0},
#    {'id': '40834724',
#     'source': 'MED',
#     'citationType': 'journal article',
#     'title': 'Biochemical Profile of Recovered Individuals With Mild COVID-19: A Cross-Sectional View at Two Different Time Points.',
#     'authorString': 'Abbas U, Ahmed I, Khalid MU, Hafeez S, Mukhtiar S, Hussain N, Nasrumminallah M, Khan MS, Babar N, Ashraf S, Kumar P.',
#     'journalAbbreviation': 'Arch Med Res',
#     'pubYear': 2025,
#     'volume': '57',
#     'issue': '1',
#     'pageInfo': '103286',
#     'citedByCount': 0},
#    {'id': '40830806',
#     'source': 'MED',
#     'citationType': 'clinical trial protocol; research-article; journal article',
#     'title': 'Randomized adaptive assessment of post COVID syndrome treatments (RAPID): a study protocol for a multicenter, randomized, controlled adaptive platform trial of treatment options for Post Covid Syndrome (PCS) on patients physical function including the first intervention specific appendix RAPID_REVIVE (reducing inflammatory activity in patients with PCS).',
#     'authorString': 'Weipert L, Telgmann RG, Anton G, Asendorf T, Chaplinskaja-Sobol I, Ciesek S, Cornely OA, Drescher S, Finke C, Friede T, Groth J, Hanß S, Hoffmann W, Huber C, Illig T, Kraus M, Krefting D, Kuhn S, Muehler A, Nauck M, Schaller J, Schmidt AC, Schmidt G, Sawitzki B, Tostmann R, Valentin H, Vehreschild M.',
#     'journalAbbreviation': 'Trials',
#     'pubYear': 2025,
#     'volume': '26',
#     'issue': '1',
#     'pageInfo': '297',
#     'citedByCount': 0},
#    {'id': '40828804',
#     'source': 'MED',
#     'citationType': 'research-article; journal article',
#     'title': 'Coping with stressful life disruptions due to long COVID: A qualitative study.',
#     'authorString': 'Wasilewski MB, Leighton J, Reis L, Vijayakumar A, English M, Sanchez K, Hitzig SL, Nelson MLA, Sheppard C, Robinson L, Steinberg R, Nguyen M, Bayley M, Daneman N, Levy C, Goulding S, Ho C, Simpson R.',
#     'journalAbbreviation': 'PLoS One',
#     'pubYear': 2025,
#     'volume': '20',
#     'issue': '8',
#     'pageInfo': 'e0329831',
#     'citedByCount': 0},
#    {'id': '40820498',
#     'source': 'MED',
#     'citationType': 'research-article; multicenter study; journal article; observational study',
#     'title': 'Clinical functioning information tool - coronavirus disease 2019 (ClinFIT COVID-19): psychometric evaluation and development of an interval-scaled functioning score across the care continuum.',
#     'authorString': 'Mukaino M, Aguiar Branco C, Alghwiri A, Amato S, Kontaxakis A, Berteanu M, Bölük Şenlikci H, Borman P, Diouane S, Fourtassi M, Gimigliano F, Hajjioui A, Hu X, Kambou S, Lin CI, I Mabrouk M, Mitsiokapa E, Nica RI, Rapidi CA, Serlenga G, Silvestri A, Tarvonen-Schröder S, Ursescu C, Viinanen A, Vorniotakis P, Selb M.',
#     'journalAbbreviation': 'J Rehabil Med',
#     'pubYear': 2025,
#     'volume': '57',
#     'pageInfo': 'jrm43227',
#     'citedByCount': 0},
#    {'id': '40819231',
#     'source': 'MED',
#     'citationType': 'review-article; review; journal article',
#     'title': 'The Challenge of Long COVID: Is the Pandemic Really Over?',
#     'authorString': 'Levin J, Bradshaw M.',
#     'journalAbbreviation': 'Public Health Rep',
#     'pubYear': 2025,
#     'pageInfo': '333549251358665',
#     'citedByCount': 0},
#    {'id': '40869200',
#     'source': 'MED',
#     'citationType': 'review; journal article',
#     'title': 'Do Long COVID and COVID Vaccine Side Effects Share Pathophysiological Picture and Biochemical Pathways?',
#     'authorString': 'Lesgards JF, Cerdan D, Perronne C.',
#     'journalAbbreviation': 'Int J Mol Sci',
#     'pubYear': 2025,
#     'volume': '26',
#     'issue': '16',
#     'pageInfo': '7879',
#     'citedByCount': 0},
#    {'id': '40934019',
#     'source': 'MED',
#     'citationType': 'research-article; journal article',
#     'title': 'Sleep quality and efficiency in adults with post-acute sequelae of COVID-19.',
#     'authorString': 'Gutiérrez-Martínez L, Reynolds WC, Abril I, González-Irizarry G, Ortiz-Acosta P, Mullington JM, Rosand J, Tanzi RE, Arnold SE, Guzmán-Vélez E.',
#     'journalAbbreviation': 'Sleep Adv',
#     'pubYear': 2025,
#     'volume': '6',
#     'issue': '3',
#     'pageInfo': 'zpaf051',
#     'citedByCount': 0},
#    {'id': '40895479',
#     'source': 'MED',
#     'citationType': 'research-article; journal article',
#     'title': 'Long-term neurocognitive outcomes of SARS-CoV-2 infection in a hamster model.',
#     'authorString': 'Ruiz-Casas C, Tarrés-Freixas F, Roca N, Pérez M, Cantero G, Martín L, Olvera A, Ruiz-Riol M, Brander C, Usai C, Vergara-Alert J, Segalés J.',
#     'journalAbbreviation': 'Front Microbiol',
#     'pubYear': 2025,
#     'volume': '16',
#     'pageInfo': '1646616',
#     'citedByCount': 0},
#    {'id': '40818641',
#     'source': 'MED',
#     'citationType': 'journal article',
#     'title': 'Determinants of quality of life in long-COVID patients with new-onset chronic pain.',
#     'authorString': 'Barrero-Santiago L, Bellosta-López P, Doménech-García V, Pérez-Pérez L, Tellería JJ, Almansa R, Montero-Cuadrado F.',
#     'journalAbbreviation': 'J Pain',
#     'pubYear': 2025,
#     'volume': '35',
#     'pageInfo': '105531',
#     'citedByCount': 0},
#    {'id': '40881360',
#     'source': 'MED',
#     'citationType': 'journal article',
#     'title': 'Sleep quality mediates the association between tea consumption and duration of COVID-19-related symptoms in middle-aged and elderly adults (aged 50 and above).',
#     'authorString': 'Fan Y, Zhu Y, Wang Y, Jiang J, Yang S, Lu J, Ma Q, Zhu H.',
#     'journalAbbreviation': 'Front Psychiatry',
#     'pubYear': 2025,
#     'volume': '16',
#     'pageInfo': '1603257',
#     'citedByCount': 0},
#    {'id': '40822898',
#     'source': 'MED',
#     'citationType': 'research-article; journal article',
#     'title': 'Individuals Recovered from Severe COVID-19 are Predispose to Develop Atrial Fibrillation.',
#     'authorString': 'Yılmaz M, Mirzaoğlu Ç.',
#     'journalAbbreviation': 'Int J Gen Med',
#     'pubYear': 2025,
#     'volume': '18',
#     'pageInfo': '4379-4390',
#     'citedByCount': 0},
#    {'id': '40790065',
#     'source': 'MED',
#     'citationType': 'journal article',
#     'title': 'Automatic detection of persistent physiological changes after COVID infection via wearable devices with potential for long COVID management.',
#     'authorString': 'Borhani S, Silva I, Damiano RJ, Feng T, Wang C, Liu L, Salvati E, Mariani S, Conroy B.',
#     'journalAbbreviation': 'Sci Rep',
#     'pubYear': 2025,
#     'volume': '15',
#     'issue': '1',
#     'pageInfo': '29443',
#     'citedByCount': 0}]}}

# %%
references
# Out:
# {'version': '6.9',
#  'hitCount': 30,
#  'request': {'id': '34308300', 'source': 'MED', 'offSet': 1, 'pageSize': 25},
#  'referenceList': {'reference': [{'id': '32150622',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Diagnostic Testing for the Novel Coronavirus.',
#     'authorString': 'Sharfstein JM, Becker SJ, Mello MM.',
#     'journalAbbreviation': 'JAMA',
#     'issue': '15',
#     'pubYear': 2020,
#     'volume': '323',
#     'pageInfo': '1437-1438',
#     'citedOrder': 1,
#     'match': 'Y',
#     'essn': '1538-3598',
#     'issn': '0098-7484'},
#    {'id': '34316551',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Cognitive deficits in people who have recovered from COVID-19.',
#     'authorString': 'Hampshire A, Trender W, Chamberlain SR, Jolly AE, Grant JE, Patrick F, Mazibuko N, Williams SC, Barnby JM, Hellyer P, Mehta MA.',
#     'journalAbbreviation': 'EClinicalMedicine',
#     'pubYear': 2021,
#     'volume': '39',
#     'pageInfo': '101044',
#     'citedOrder': 2,
#     'match': 'Y',
#     'essn': '2589-5370',
#     'issn': '2589-5370'},
#    {'id': '33576815',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Age- and Sex-Associated Variations in the Sensitivity of Serological Tests Among Individuals Infected With SARS-CoV-2.',
#     'authorString': 'Vashisht R, Patel A, Crews BO, Garner OB, Dahm L, Wilson C, Butte AJ.',
#     'journalAbbreviation': 'JAMA Netw Open',
#     'issue': '2',
#     'pubYear': 2021,
#     'volume': '4',
#     'pageInfo': 'e210337',
#     'citedOrder': 3,
#     'match': 'Y',
#     'essn': '2574-3805',
#     'issn': '2574-3805'},
#    {'id': '32644129',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Persistent Symptoms in Patients After Acute COVID-19.',
#     'authorString': 'Carfi A, Bernabei R, Landi F; Gemelli Against COVID-19 Post-Acute Care Study Group.',
#     'journalAbbreviation': 'JAMA',
#     'issue': '6',
#     'pubYear': 2020,
#     'volume': '324',
#     'pageInfo': '603-605',
#     'citedOrder': 4,
#     'match': 'Y',
#     'essn': '1538-3598',
#     'issn': '0098-7484'},
#    {'id': '33461210',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Evolution of antibody immunity to SARS-CoV-2.',
#     'authorString': "Gaebler C, Wang Z, Lorenzi JCC, Muecksch F, Finkin S, Tokuyama M, Cho A, Jankovic M, Schaefer-Babajew D, Oliveira TY, Cipolla M, Viant C, Barnes CO, Bram Y, Breton G, Hagglof T, Mendoza P, Hurley A, Turroja M, Gordon K, Millard KG, Ramos V, Schmidt F, Weisblum Y, Jha D, Tankelevich M, Martinez-Delgado G, Yee J, Patel R, Dizon J, Unson-O'Brien C, Shimeliovich I, Robbiani DF, Zhao Z, Gazumyan A, Schwartz RE, Hatziioannou T, Bjorkman PJ, Mehandru S, Bieniasz PD, Caskey M, Nussenzweig MC.",
#     'journalAbbreviation': 'Nature',
#     'issue': '7851',
#     'pubYear': 2021,
#     'volume': '591',
#     'pageInfo': '639-644',
#     'citedOrder': 5,
#     'match': 'Y',
#     'essn': '1476-4687',
#     'issn': '0028-0836'},
#    {'id': '33301459',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'False-negative results of initial RT-PCR assays for COVID-19: A systematic review.',
#     'authorString': 'Arevalo-Rodriguez I, Buitrago-Garcia D, Simancas-Racines D, Zambrano-Achig P, Del Campo R, Ciapponi A, Sued O, Martinez-Garcia L, Rutjes AW, Low N, Bossuyt PM, Perez-Molina JA, Zamora J.',
#     'journalAbbreviation': 'PLoS One',
#     'issue': '12',
#     'pubYear': 2020,
#     'volume': '15',
#     'pageInfo': 'e0242958',
#     'citedOrder': 6,
#     'match': 'Y',
#     'essn': '1932-6203',
#     'issn': '1932-6203'},
#    {'id': '32422057',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Variation in False-Negative Rate of Reverse Transcriptase Polymerase Chain Reaction-Based SARS-CoV-2 Tests by Time Since Exposure.',
#     'authorString': 'Kucirka LM, Lauer SA, Laeyendecker O, Boon D, Lessler J.',
#     'journalAbbreviation': 'Ann Intern Med',
#     'issue': '4',
#     'pubYear': 2020,
#     'volume': '173',
#     'pageInfo': '262-267',
#     'citedOrder': 7,
#     'match': 'Y',
#     'essn': '1539-3704',
#     'issn': '0003-4819'},
#    {'id': '33071931',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Characterization of Post-exertional Malaise in Patients With Myalgic Encephalomyelitis/Chronic Fatigue Syndrome.',
#     'authorString': 'Stussman B, Williams A, Snow J, Gavin A, Scott R, Nath A, Walitt B.',
#     'journalAbbreviation': 'Front Neurol',
#     'pubYear': 2020,
#     'volume': '11',
#     'pageInfo': '1025',
#     'citedOrder': 8,
#     'match': 'Y',
#     'essn': '1664-2295',
#     'issn': '1664-2295'},
#    {'id': '32920235',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Covid-19 hyperinflammation and post-Covid-19 illness may be rooted in mast cell activation syndrome.',
#     'authorString': 'Afrin LB, Weinstock LB, Molderings GJ.',
#     'journalAbbreviation': 'Int J Infect Dis',
#     'pubYear': 2020,
#     'volume': '100',
#     'pageInfo': '327-332',
#     'citedOrder': 9,
#     'match': 'Y',
#     'essn': '1878-3511',
#     'issn': '1201-9712'},
#    {'id': '33252665',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Long COVID in the Faroe Islands: A Longitudinal Study Among Nonhospitalized Patients.',
#     'authorString': 'Petersen MS, Kristiansen MF, Hanusson KD, Danielsen ME, A Steig B, Gaini S, Strom M, Weihe P.',
#     'journalAbbreviation': 'Clin Infect Dis',
#     'issue': '11',
#     'pubYear': 2021,
#     'volume': '73',
#     'pageInfo': 'e4058-e4063',
#     'citedOrder': 10,
#     'match': 'Y',
#     'essn': '1537-6591',
#     'issn': '1058-4838'},
#    {'id': '32730238',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Symptom Duration and Risk Factors for Delayed Return to Usual Health Among Outpatients with COVID-19 in a Multistate Health Care Systems Network - United States, March-June 2020.',
#     'authorString': 'Tenforde MW, Kim SS, Lindsell CJ, Billig Rose E, Shapiro NI, Files DC, Gibbs KW, Erickson HL, Steingrub JS, Smithline HA, Gong MN, Aboodi MS, Exline MC, Henning DJ, Wilson JG, Khan A, Qadir N, Brown SM, Peltan ID, Rice TW, Hager DN, Ginde AA, Stubblefield WB, Patel MM, Self WH, Feldstein LR; IVY Network Investigators; CDC COVID-19 Response Team; IVY Network Investigators , Hart KW, McClellan R, Dorough L, Dzuris N, Griggs EP, Kassem AM, Marcet PL, Ogokeh CE, Sciarratta CN, Siddula A, Smith ER, Wu MJ.',
#     'journalAbbreviation': 'MMWR Morb Mortal Wkly Rep',
#     'issue': '30',
#     'pubYear': 2020,
#     'volume': '69',
#     'pageInfo': '993-998',
#     'citedOrder': 11,
#     'match': 'Y',
#     'essn': '1545-861X',
#     'issn': '0149-2195'},
#    {'id': '15296678',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Measuring fatigue in sarcoidosis: the Fatigue Assessment Scale (FAS).',
#     'authorString': 'De Vries J, Michielsen H, Van Heck GL, Drent M.',
#     'journalAbbreviation': 'Br J Health Psychol',
#     'issue': 'Pt 3',
#     'pubYear': 2004,
#     'volume': '9',
#     'pageInfo': '279-291',
#     'citedOrder': 12,
#     'match': 'Y',
#     'essn': '2044-8287',
#     'issn': '1359-107X'},
#    {'id': '32784198',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Management of post-acute covid-19 in primary care.',
#     'authorString': "Greenhalgh T, Knight M, A'Court C, Buxton M, Husain L.",
#     'journalAbbreviation': 'BMJ',
#     'pubYear': 2020,
#     'volume': '370',
#     'pageInfo': 'm3026',
#     'citedOrder': 13,
#     'match': 'Y',
#     'essn': '1756-1833',
#     'issn': '0959-8138'},
#    {'id': '32861312',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Surveillance is underestimating the burden of the COVID-19 pandemic.',
#     'authorString': 'Alwan NA.',
#     'journalAbbreviation': 'Lancet',
#     'issue': '10252',
#     'pubYear': 2020,
#     'volume': '396',
#     'pageInfo': 'e24',
#     'citedOrder': 14,
#     'match': 'Y',
#     'essn': '1474-547X',
#     'issn': '0140-6736'},
#    {'id': '32448084',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Analytical comparisons of SARS-COV-2 detection by qRT-PCR and ddPCR with multiple primer/probe sets.',
#     'authorString': 'Liu X, Feng J, Zhang Q, Guo D, Zhang L, Suo T, Hu W, Guo M, Wang X, Huang Z, Xiong Y, Chen G, Chen Y, Lan K.',
#     'journalAbbreviation': 'Emerg Microbes Infect',
#     'issue': '1',
#     'pubYear': 2020,
#     'volume': '9',
#     'pageInfo': '1175-1179',
#     'citedOrder': 15,
#     'match': 'Y',
#     'essn': '2222-1751',
#     'issn': '2222-1751'},
#    {'id': '33199035',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'How and why patients made Long Covid.',
#     'authorString': 'Callard F, Perego E.',
#     'journalAbbreviation': 'Soc Sci Med',
#     'pubYear': 2020,
#     'volume': '268',
#     'pageInfo': '113426',
#     'citedOrder': 16,
#     'match': 'Y',
#     'essn': '1873-5347',
#     'issn': '0277-9536'},
#    {'id': '33285216',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Clinical, virological and imaging profile in patients with prolonged forms of COVID-19: A cross-sectional study.',
#     'authorString': 'Salmon-Ceron D, Slama D, De Broucker T, Karmochkine M, Pavie J, Sorbets E, Etienne N, Batisse D, Spiridon G, Baut VL, Meritet JF, Pichard E, Canoui-Poitrine F; APHP COVID-19 research collaboration.',
#     'journalAbbreviation': 'J Infect',
#     'issue': '2',
#     'pubYear': 2020,
#     'volume': '82',
#     'pageInfo': 'e1-e4',
#     'citedOrder': 17,
#     'match': 'Y',
#     'essn': '1532-2742',
#     'issn': '0163-4453'},
#    {'id': '32599178',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'COVID-19 cardiac injury: Implications for long-term surveillance and outcomes in survivors.',
#     'authorString': 'Mitrani RD, Dabas N, Goldberger JJ.',
#     'journalAbbreviation': 'Heart Rhythm',
#     'issue': '11',
#     'pubYear': 2020,
#     'volume': '17',
#     'pageInfo': '1984-1990',
#     'citedOrder': 18,
#     'match': 'Y',
#     'essn': '1556-3871',
#     'issn': '1547-5271'},
#    {'id': '32150527',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Detection of Novel Coronavirus by RT-PCR in Stool Specimen from Asymptomatic Child, China.',
#     'authorString': 'Tang A, Tong ZD, Wang HL, Dai YX, Li KF, Liu JN, Wu WJ, Yuan C, Yu ML, Li P, Yan JB.',
#     'journalAbbreviation': 'Emerg Infect Dis',
#     'issue': '6',
#     'pubYear': 2020,
#     'volume': '26',
#     'pageInfo': '1337-1339',
#     'citedOrder': 19,
#     'match': 'Y',
#     'essn': '1080-6059',
#     'issn': '1080-6040'},
#    {'id': '32932582',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Care Dependency in Non-Hospitalized Patients with COVID-19.',
#     'authorString': "Vaes AW, Machado FVC, Meys R, Delbressine JM, Goertz YMJ, Van Herck M, Houben-Wilke S, Franssen FME, Vijlbrief H, Spies Y, Van 't Hul AJ, Burtin C, Janssen DJA, Spruit MA.",
#     'journalAbbreviation': 'J Clin Med',
#     'issue': '9',
#     'pubYear': 2020,
#     'volume': '9',
#     'pageInfo': 'E2946',
#     'citedOrder': 20,
#     'match': 'Y',
#     'essn': '2077-0383',
#     'issn': '2077-0383'},
#    {'id': '33987484',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Patient-Led Research Collaborative: embedding patients in the Long COVID narrative.',
#     'authorString': 'McCorkell L, S Assaf G, E Davis H, Wei H, Akrami A.',
#     'journalAbbreviation': 'Pain Rep',
#     'issue': '1',
#     'pubYear': 2021,
#     'volume': '6',
#     'pageInfo': 'e913',
#     'citedOrder': 21,
#     'match': 'Y',
#     'essn': '2471-2531',
#     'issn': '2471-2531'},
#    {'id': '34172986',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Neurologic manifestations of nonhospitalized patients with COVID-19 in Wuhan, China.',
#     'authorString': 'Ding H, Yin S, Cheng Y, Cai Y, Huang W, Deng W.',
#     'journalAbbreviation': 'MedComm (2020)',
#     'issue': '2',
#     'pubYear': 2020,
#     'volume': '1',
#     'pageInfo': '253-256',
#     'citedOrder': 22,
#     'match': 'Y',
#     'essn': '2688-2663',
#     'issn': '2688-2663'},
#    {'id': '29876157',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Postural Orthostatic Tachycardia Syndrome and Its Unusual Presenting Complaints in Women: A Literature Minireview.',
#     'authorString': 'Anjum I, Sohail W, Hatipoglu B, Wilson R.',
#     'journalAbbreviation': 'Cureus',
#     'issue': '4',
#     'pubYear': 2018,
#     'volume': '10',
#     'pageInfo': 'e2435',
#     'citedOrder': 23,
#     'match': 'Y',
#     'essn': '2168-8184',
#     'issn': '2168-8184'},
#    {'id': '32398230',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': 'Interpreting a covid-19 test result.',
#     'authorString': 'Watson J, Whiting PF, Brush JE.',
#     'journalAbbreviation': 'BMJ',
#     'pubYear': 2020,
#     'volume': '369',
#     'pageInfo': 'm1808',
#     'citedOrder': 24,
#     'match': 'Y',
#     'essn': '1756-1833',
#     'issn': '0959-8138'},
#    {'id': '33433583',
#     'source': 'MED',
#     'citationType': 'JOURNAL ARTICLE',
#     'title': "Health Workers' Antibody Levels Wane After SARS-CoV-2 Infection.",
#     'authorString': 'Kuehn BM.',
#     'journalAbbreviation': 'JAMA',
#     'issue': '2',
#     'pubYear': 2021,
#     'volume': '325',
#     'pageInfo': '122',
#     'citedOrder': 25,
#     'match': 'Y',
#     'essn': '1538-3598',
#     'issn': '0098-7484'}]}}

# %%
# Supplementary data and cross-references
supp_files = article_client.get_supplementary_files(article.get('result', {}).get('pmcid', ''))
db_links = article_client.get_database_links("MED", "3164476")
print(f"Supplementary files: {len(supp_files) if supp_files else 0}")
print(f"Database links: {len(db_links) if db_links else 0}")
db_links
# Out:
# Supplementary files: 4539396
# Database links: 2
# /home/jhe24/AID-PAIS/pyEuropePMC_project/src/pyeuropepmc/article.py:328: UserWarning: 'hitCount' key not found in response dictionary for database links
#   warn_if_empty_hitcount(result, context="database links")
# {'version': '6.9',
#  'request': {'id': '3164476',
#   'source': 'MED',
#   'offSet': 1,
#   'pageSize': 25,
#   'semanticType': ''}}

# %%
# Visualize supplementary files metadata if available
import zipfile
import io
import pandas as pd
from IPython.display import display

if supp_files and isinstance(supp_files, (bytes, bytearray)) and len(supp_files) > 0:
    try:
        with zipfile.ZipFile(io.BytesIO(supp_files)) as z:
            file_list = z.namelist()
            print(f"Supplementary ZIP contains {len(file_list)} files:")
            if file_list:
                df = pd.DataFrame({"File Name": file_list})
                display(df)
            else:
                print("ZIP is empty.")
    except Exception as e:
        print(f"Could not read ZIP: {e}")
else:
    print("No supplementary files returned or not a valid ZIP.")
# Out:
# Supplementary ZIP contains 13 files:
#     File Name
# 0     gr1.jpg
# 1     gr2.jpg
# 2     gr3.jpg
# 3     gr4.jpg
# 4     gr5.jpg
# 5     gr6.jpg
# 6     gr7.jpg
# 7     gr8.jpg
# 8     gr9.jpg
# 9    gr10.jpg
# 10   gr11.jpg
# 11   gr12.jpg
# 12  mmc1.docx

# %%
# Robust error handling demo
try:
    bad_article = article_client.get_article_details("MED", "00000000")
    print(bad_article)
except Exception as e:
    print(f"Handled error: {e}")
# Out:
# {'version': '6.9', 'hitCount': 0, 'request': {'resultType': 'CORE', 'id': '00000000', 'source': 'MED'}, 'result': {}}
# /home/jhe24/AID-PAIS/pyEuropePMC_project/src/pyeuropepmc/article.py:84: UserWarning: No results found (hitCount=0) for article details
#   warn_if_empty_hitcount(result, context="article details")

# %% [markdown]
# ## Demo Summary
#
# - Article metadata, citations, references, supplementary files, and cross-references retrieved in seconds.
# - All main ArticleClient features shown in minimal code.
# - Errors handled gracefully.
#
# **Ready for production and further exploration!**
